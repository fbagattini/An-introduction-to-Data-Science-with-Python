# %%
import pandas as pd

# %%
df_train = pd.read_csv('../data/train.csv', header = 0, index_col = 'PassengerId')

# %%
df_train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
gender_probs = df_train.Sex.value_counts() / df_train.shape[0]
survival_probs = df_train.groupby('Sex').Survived.mean()

# %%
gender_probs
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
survival_probs
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
gender_probs['female']*survival_probs['female']
# Out:
# 0.2615039281705948

# %%
gender_probs['female']*survival_probs['female'] + gender_probs['male']*(1-survival_probs['male'])
# Out:
# 0.7867564534231202

# %%
gender_probs['female']*survival_probs['female'] + gender_probs['male']*survival_probs['male']
# Out:
# 0.3838383838383838

# %%
df_train.Survived.mean()
# Out:
# 0.3838383838383838
